# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data = pd.read_csv("/Users/ravitiwari/Desktop/MY Data/work/garments_worker_productivity.csv",index_col="date", parse_dates=True)
Data
# Out:
#              quarter  department        day  team  targeted_productivity  \
# date
# 2015-01-01  Quarter1      sweing   Thursday     8                   0.80
# 2015-01-01  Quarter1  finishing    Thursday     1                   0.75
# 2015-01-01  Quarter1      sweing   Thursday    11                   0.80
# 2015-01-01  Quarter1      sweing   Thursday    12                   0.80
# 2015-01-01  Quarter1      sweing   Thursday     6                   0.80
# ...              ...         ...        ...   ...                    ...
# 2015-03-11  Quarter2   finishing  Wednesday    10                   0.75
# 2015-03-11  Quarter2   finishing  Wednesday     8                   0.70
# 2015-03-11  Quarter2   finishing  Wednesday     7                   0.65
# 2015-03-11  Quarter2   finishing  Wednesday     9                   0.75
# 2015-03-11  Quarter2   finishing  Wednesday     6                   0.70
#
#               smv     wip  over_time  incentive  idle_time  idle_men  \
# date
# ...

# %%
Data['department'] = Data['department'].map({ 'finishing ':'finishing','sweing':'sweing','finishing':'finishing'})

# %%
Data.isnull().sum()
# Out:
# quarter                    0
# department                 0
# day                        0
# team                       0
# targeted_productivity      0
# smv                        0
# wip                      506
# over_time                  0
# incentive                  0
# idle_time                  0
# idle_men                   0
# no_of_style_change         0
# no_of_workers              0
# actual_productivity        0
# dtype: int64

# %%
Data.shape
# Out:
# (1197, 14)

# %%
Data.columns
# Out:
# Index(['quarter', 'department', 'day', 'team', 'targeted_productivity', 'smv',
#        'wip', 'over_time', 'incentive', 'idle_time', 'idle_men',
#        'no_of_style_change', 'no_of_workers', 'actual_productivity'],
#       dtype='object')

# %%
plt.figure(figsize = (20,6))
ax=sns.lineplot(y='targeted_productivity',x='date' ,data =Data,)
ax=sns.lineplot(y= 'actual_productivity',x='date',data=Data)
ax.set(ylabel = 'Productivity')
plt.show()

# %%
plt.figure(figsize = (6,6))
ax=sns.violinplot(y='targeted_productivity',x='department' ,data =Data, box = True, Point = 'all')
ax=sns.violinplot(y= 'actual_productivity',x='department',data=Data,box = True)
ax.set(ylabel = 'Productivity')
plt.show()

# %%
plt.figure(figsize = (20,10))
ax=sns.lineplot(y='targeted_productivity',x='date' ,data =Data,hue= 'department' )
ax.set(ylabel = 'Target Productivity')
plt.show()

# %%
plt.figure(figsize = (20,10))
ax=sns.lineplot(y= 'actual_productivity',x='date',data=Data,hue= 'department')
ax.set(ylabel = 'actual Productivity')
plt.show()

# %%
plt.figure(figsize = (20,10))
ax=sns.lineplot(y='targeted_productivity',x='date' ,data =Data,hue= 'department' )
ax.set(ylabel = 'Target Productivity')
plt.show()
